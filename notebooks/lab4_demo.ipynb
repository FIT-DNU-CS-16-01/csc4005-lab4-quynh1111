# %% [markdown]
# # CSC4005 Lab 4 Demo – CRNN for UrbanSound8K
# Notebook này dùng để minh họa luồng xử lý chính. Khi nộp bài, sinh viên nên chạy bằng command line để có output đầy đủ.

# %%
# !python -m src.train --help

# %% [markdown]
# ## Chạy baseline
# Thay `/duong_dan/UrbanSound8K` bằng đường dẫn thật trên máy.

# %%
# !python -m src.train --config configs/baseline_logmel_crnn.json --data_dir /duong_dan/UrbanSound8K --use_wandb
